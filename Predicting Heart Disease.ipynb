# %% [markdown]
# # Data Analysis

# %%
# importing packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Dataset

# %%
# importing dataset

data = pd.read_csv("UCI Heart Disease Dataset.csv")
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ### Get Info about Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# ### Corrilation Between Fields

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Visualize no. of patients having a heart disease and not having a heart disease

# %%
# count no. of pacients having and not having heart deceses
heart_disease_count = data['target'].value_counts()

# plot the count
plt.style.use('dark_background')
plt.figure(figsize=(8,6))
heart_disease_count.plot(kind='bar', color=['r','g'])
plt.title('Number of Patients with Heart Disease')
plt.xlabel('Heart Disease Presence', color='y')
plt.ylabel('Number of Patients',color='y')
plt.xticks([0, 1], ['No Heart Disease', 'Heart Disease'], rotation=0)
plt.show()

# %% [markdown]
# ###  Visualize the age and whether a patient has disease or not

# %%
# visualize age with patients have disecse or not
#sns.set(style="whitegrid")
plt.style.use('dark_background')
plt.figure(figsize=(24,18))
sns.countplot(x="age", hue= "target", data=data)
plt.title("Distrubusion of patient by age and heart Disecse", color="g")
plt.xlabel("Age", color= "y")
plt.ylabel("Count", color="y")
plt.legend(title="Heart Disecse", labels=["Yes","No"])
plt.show()

# %% [markdown]
# ### Visualize correlation between all features using a heat map

# %%
# correlation between all features
corr_matrix = data.corr()

plt.style.use("dark_background")
plt.figure(figsize=(24,12))
sns.heatmap(corr_matrix, annot=True, cmap="summer",fmt= "2f",linewidths=.5)
plt.title("Correlation Between all Features", color="g")
plt.show()

# %% [markdown]
# # Logistic Regrassion

# %%
#Logistic Regrassion

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix , accuracy_score

X= data.drop(columns=["target"])
y= data["target"]
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3,random_state=42)
logistic_model= LogisticRegression()
logistic_model.fit(X_train,y_train)
y_pred= logistic_model.predict(X_test)

#confusion Matrix
conf_matrix=confusion_matrix(y_test,y_pred)
print("Confusion Matrix")
print(conf_matrix)

#accuracy Score
accuracy =accuracy_score(y_test,y_pred)
print("Accuracy Score :", accuracy)
# Out:
# Confusion Matrix
# [[32  9]
#  [ 8 42]]
# Accuracy Score : 0.8131868131868132
# c:\Users\vishw\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Decision Tree

# %%
# Decision Tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.tree import export_graphviz
import graphviz
import matplotlib.pyplot as plt

X = data.drop(columns=['target'])  # Features
y = data['target']  # Target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
decision_tree_model = DecisionTreeClassifier()
decision_tree_model.fit(X_train, y_train)
y_pred = decision_tree_model.predict(X_test)

# confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy Score:", accuracy)
# Out:
# Confusion Matrix:
# [[33  8]
#  [16 34]]
# Accuracy Score: 0.7362637362637363

# %% [markdown]
# # Random Forest

# %%
# Random Forest

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.tree import export_graphviz
import graphviz
import matplotlib.pyplot as plt

X = data.drop(columns=['target'])  
y = data['target']  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
random_forest_model = RandomForestClassifier()
random_forest_model.fit(X_train, y_train)
y_pred = random_forest_model.predict(X_test)

# confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy Score:", accuracy)
# Out:
# Confusion Matrix:
# [[32  9]
#  [ 8 42]]
# Accuracy Score: 0.8131868131868132

# %% [markdown]
# # Comparison Between Models

# %%
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

# Initialize lists to store metrics for each model
conf_matrices = []
class_reports = []
accuracies = []
precisions = []
recalls = []
f1_scores = []

# List of classifiers
classifiers = [
    ("Logistic Regression", logistic_model),
    ("Decision Tree", decision_tree_model),
    ("Random Forest", random_forest_model)
]

# Iterate over each classifier
for clf_name, clf in classifiers:
    # Predict on the test set
    y_pred = clf.predict(X_test)

    # Calculate confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)
    conf_matrices.append((clf_name, conf_matrix))

    # Calculate classification report
    class_report = classification_report(y_test, y_pred)
    class_reports.append((clf_name, class_report))

    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append((clf_name, accuracy))

    # Calculate precision
    precision = precision_score(y_test, y_pred)
    precisions.append((clf_name, precision))

    # Calculate recall
    recall = recall_score(y_test, y_pred)
    recalls.append((clf_name, recall))

    # Calculate F1 score
    f1 = f1_score(y_test, y_pred)
    f1_scores.append((clf_name, f1))

    # Plot confusion matrix as a heatmap
    plt.figure(figsize=(4,3))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="summer",
                xticklabels=['No Disease', 'Disease'],
                yticklabels=['No Disease', 'Disease'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title(f'Confusion Matrix - {clf_name}')
    plt.show()

# Print confusion matrices
for clf_name, conf_matrix in conf_matrices:
    print(f"Confusion Matrix - {clf_name}:")
    print(conf_matrix)
    print()

# Print classification reports
for clf_name, class_report in class_reports:
    print(f"Classification Report - {clf_name}:")
    print(class_report)
    print()

# Print accuracy scores
print("Accuracy Scores:")
for clf_name, accuracy in accuracies:
    print(f"{clf_name}: {accuracy:.4f}")

# Print precision scores
print("Precision Scores:")
for clf_name, precision in precisions:
    print(f"{clf_name}: {precision:.4f}")

# Print recall scores
print("Recall Scores:")
for clf_name, recall in recalls:
    print(f"{clf_name}: {recall:.4f}")

# Print F1 scores
print("F1 Scores:")
for clf_name, f1 in f1_scores:
    print(f"{clf_name}: {f1:.4f}")
# Out:
# Confusion Matrix - Logistic Regression:
# [[32  9]
#  [ 8 42]]
#
# Confusion Matrix - Decision Tree:
# [[33  8]
#  [16 34]]
#
# Confusion Matrix - Random Forest:
# [[32  9]
#  [ 8 42]]
#
# Classification Report - Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79        41
#            1       0.82      0.84      0.83        50
#
#     accuracy                           0.81        91
#    macro avg       0.81      0.81      0.81        91
# weighted avg       0.81      0.81      0.81        91
#
#
# Classification Report - Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        41
#            1       0.81      0.68      0.74        50
#
#     accuracy                           0.74        91
#    macro avg       0.74      0.74      0.74        91
# weighted avg       0.75      0.74      0.74        91
#
#
# ...
